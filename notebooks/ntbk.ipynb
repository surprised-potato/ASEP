# %%
import numpy as np

#coordinates in meters
nodes = np.array([
    [0,0],      #node a 0
    [1,0.75],   #node b 1
    [2,0.75],   #node c 2
    [3,0],      #node d 3
    [1,0],      #node e 4
    [2,0]       #node f 5
])

elements = np.array([
    [0,1],  #element ab
    [1,2],  #element bc
    [2,3],  #element cd
    [1,4],   #element ae
    [4,5],   #element ef
    [5,3],   #element fd
    [1,4],   #element be
    [4,1],   #element ec
    [2,5],   #element cf
])

loads = np.array([
    [0,0],    #node a
    [0,0],    #node b
    [80000,0],    #node c
    [0,0],#node d
    [0,0],    #node e
    [0,-50000]     #node f
])

n = {'a':0, 'b':1, 'c':2, 'd':3, 'e':4, 'f':5}

fixed_dofs = [
    []
]
# Out:
# <>:17: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:17: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\ACER\AppData\Local\Temp\ipykernel_25180\2713800712.py:17: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   [1,4]   #element ae
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 17
#       3 #coordinates in meters
#       4 nodes = np.array([
#       5     [0,0],      #node a 0
#       6     [1,0.75],   #node b 1
#    (...)     10     [2,0]       #node f 5
#      11 ])
#      13 elements = np.array([
#      14     [0,1],  #element ab
#      15     [1,2],  #element bc
#      16     [2,3],  #element cd
# ---> 17     [1,4]   #element ae
#      18     [4,5]   #element ef
#      19     [5,3]   #element fd
#      20     [1,4]   #element be
#      21     [4,1]   #element ec
#      22     [2,5]   #element cf
#      23 ])
#      25 loads = np.array([
#      26     [0,0],    #node a
#      27     [0,0],    #node b
#    (...)     31     [0,-50000]     #node f
#      32 ])
#      34 n = {'a':0, 'b':1, 'c':2, 'd':3, 'e':4, 'f':5}
#
# TypeError: list indices must be integers or slices, not tuple

# %%
import ipywidgets as widgets
from IPython.display import display

# Create a FloatText widget
float_widget = widgets.FloatText(
    value=7.5,
    description='Any float:',
    disabled=False
)

# Display the widget
display(float_widget)
# Out:
# FloatText(value=7.5, description='Any float:')
